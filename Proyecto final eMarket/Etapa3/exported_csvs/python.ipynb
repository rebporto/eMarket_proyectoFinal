# %%
import pandas as pd

# %%
df=pd.read_csv('proveedores.csv', encoding='UTF-8-SIG')
df
# Out:
#     ProveedorID                                Compania  \
# 0             1                          Exotic Liquids
# 1             2              New Orleans Cajun Delights
# 2             3               Grandma Kelly's Homestead
# 3             4                           Tokyo Traders
# 4             5      Cooperativa de Quesos 'Las Cabras'
# 5             6                                Mayumi's
# 6             7                           Pavlova, Ltd.
# 7             8                Specialty Biscuits, Ltd.
# 8             9                        PB Kneckebred AB
# 9            10               Refrescos Americanas LTDA
# 10           11             Heli Seewaren GmbH & Co. KG
# 11           12       Plutzer Lebensmittelgroemerkte AG
# 12           13  Nord-Ost-Fisch Handelsgesellschaft mbH
# 13           14                 Formaggi Fortini s.r.l.
# 14           15                         Norske Meierier
# 15           16                       Bigfoot Breweries
# ...

# %%
df=df.replace('�','e', regex=True)

# %%
CLIENTES

# %%
df2=pd.read_csv('clientes.csv', encoding='UTF-8-SIG')
df2
# Out:
#    ClienteID                            Compania                 Contacto  \
# 0      ALFKI                 Alfreds Futterkiste             Maria Anders
# 1      ANATR  Ana Trujillo Emparedados y helados             Ana Trujillo
# 2      ANTON             Antonio Moreno Taquer?a           Antonio Moreno
# 3      AROUT                     Around the Horn             Thomas Hardy
# 4      BERGS                  Berglunds snabbk?p       Christina Berglund
# ..       ...                                 ...                      ...
# 86     WARTH                      Wartian Herkku         Pirkko Koskitalo
# 87     WELLI              Wellington Importadora            Paula Parente
# 88     WHITC                White Clover Markets           Karl Jablonski
# 89     WILMK                         Wilman Kala          Matti Karttunen
# 90     WOLZA                      Wolski  Zajazd  Zbyszek Piestrzeniewicz
#
#                        Titulo                      Direccion       Ciudad  \
# ...

# %%
df2=df2.replace('?s:e', regex=True)
df2
# Out:
#    ClienteID                            Compania                 Contacto  \
# 0      ALFKI                 Alfreds Futterkiste             Maria Anders
# 1      ANATR  Ana Trujillo Emparedados y helados             Ana Trujillo
# 2      ANTON             Antonio Moreno Taquer?a           Antonio Moreno
# 3      AROUT                     Around the Horn             Thomas Hardy
# 4      BERGS                  Berglunds snabbk?p       Christina Berglund
# ..       ...                                 ...                      ...
# 86     WARTH                      Wartian Herkku         Pirkko Koskitalo
# 87     WELLI              Wellington Importadora            Paula Parente
# 88     WHITC                White Clover Markets           Karl Jablonski
# 89     WILMK                         Wilman Kala          Matti Karttunen
# 90     WOLZA                      Wolski  Zajazd  Zbyszek Piestrzeniewicz
#
#                        Titulo                      Direccion       Ciudad  \
# ...

# %%
FACTURA

# %%
df3=pd.read_csv('facturas.csv')
df3
# Out:
#      FacturaID ClienteID  EmpleadoID         FechaFactura  \
# 0        10248     VINET           5  1996-07-04 00:00:00
# 1        10249     TOMSP           6  1996-07-05 00:00:00
# 2        10250     HANAR           4  1996-07-08 00:00:00
# 3        10251     VICTE           3  1996-07-08 00:00:00
# 4        10252     SUPRD           4  1996-07-09 00:00:00
# ..         ...       ...         ...                  ...
# 825      11073     PERIC           2  1998-05-05 00:00:00
# 826      11074     SIMOB           7  1998-05-06 00:00:00
# 827      11075     RICSU           8  1998-05-06 00:00:00
# 828      11076     BONAP           4  1998-05-06 00:00:00
# 829      11077     RATTC           1  1998-05-06 00:00:00
#
#            FechaRegistro           FechaEnvio  EnvioVia  Transporte  \
# 0    1996-08-01 00:00:00  1996-07-16 00:00:00         3       32.38
# 1    1996-08-16 00:00:00  1996-07-10 00:00:00         1       11.61
# ...

# %%
df3=df3.replace('�','e', regex=True)
df3
# Out:
#      FacturaID ClienteID  EmpleadoID         FechaFactura  \
# 0        10248     VINET           5  1996-07-04 00:00:00
# 1        10249     TOMSP           6  1996-07-05 00:00:00
# 2        10250     HANAR           4  1996-07-08 00:00:00
# 3        10251     VICTE           3  1996-07-08 00:00:00
# 4        10252     SUPRD           4  1996-07-09 00:00:00
# ..         ...       ...         ...                  ...
# 825      11073     PERIC           2  1998-05-05 00:00:00
# 826      11074     SIMOB           7  1998-05-06 00:00:00
# 827      11075     RICSU           8  1998-05-06 00:00:00
# 828      11076     BONAP           4  1998-05-06 00:00:00
# 829      11077     RATTC           1  1998-05-06 00:00:00
#
#            FechaRegistro           FechaEnvio  EnvioVia  Transporte  \
# 0    1996-08-01 00:00:00  1996-07-16 00:00:00         3       32.38
# 1    1996-08-16 00:00:00  1996-07-10 00:00:00         1       11.61
# ...

# %%
df3=df3.replace('�','e', regex=True)
df3
# Out:
#      FacturaID ClienteID  EmpleadoID FechaFactura FechaRegistro  FechaEnvio  \
# 0        10248     VINET           5   1996-07-04    1996-08-01  1996-07-16
# 1        10249     TOMSP           6   1996-07-05    1996-08-16  1996-07-10
# 2        10250     HANAR           4   1996-07-08    1996-08-05  1996-07-12
# 3        10251     VICTE           3   1996-07-08    1996-08-05  1996-07-15
# 4        10252     SUPRD           4   1996-07-09    1996-08-06  1996-07-11
# ..         ...       ...         ...          ...           ...         ...
# 825      11073     PERIC           2   1998-05-05    1998-06-02         NaN
# 826      11074     SIMOB           7   1998-05-06    1998-06-03         NaN
# 827      11075     RICSU           8   1998-05-06    1998-06-03         NaN
# 828      11076     BONAP           4   1998-05-06    1998-06-03         NaN
# 829      11077     RATTC           1   1998-05-06    1998-06-03         NaN
#
#      EnvioVia  Transporte                 NombreEnvio  \
# ...

# %%
df3.to_csv("facturas.csv", index=False)

# %%
PRODUCTOS

# %%
df=pd.read_csv('productos.csv')
df
# Out:
#     ProductoID                   ProductoNombre  ProveedorID  CategoriaID  \
# 0            1                             Chai            1            1
# 1            2                            Chang            1            1
# 2            3                    Aniseed Syrup            1            2
# 3            4     Chef Anton's Cajun Seasoning            2            2
# 4            5           Chef Anton's Gumbo Mix            2            2
# ..         ...                              ...          ...          ...
# 72          73                       R�d Kaviar           17            8
# 73          74                    Longlife Tofu            4            7
# 74          75             Rh�nbr�u Klosterbier           12            1
# 75          76                     Lakkalik��ri           23            1
# 76          77  Original Frankfurter gr�ne So�e           12            2
#
#       CantidadPorUnidad  PrecioUnitario  UnidadesStock  UnidadesPedidas  \
# ...

# %%
df=df.replace('�','e', regex=True)
df
# Out:
#     ProductoID                   ProductoNombre  ProveedorID  CategoriaID  \
# 0            1                             Chai            1            1
# 1            2                            Chang            1            1
# 2            3                    Aniseed Syrup            1            2
# 3            4     Chef Anton's Cajun Seasoning            2            2
# 4            5           Chef Anton's Gumbo Mix            2            2
# ..         ...                              ...          ...          ...
# 72          73                       Red Kaviar           17            8
# 73          74                    Longlife Tofu            4            7
# 74          75             Rhenbreu Klosterbier           12            1
# 75          76                     Lakkalikeeri           23            1
# 76          77  Original Frankfurter grene Soee           12            2
#
#       CantidadPorUnidad  PrecioUnitario  UnidadesStock  UnidadesPedidas  \
# ...

# %%
df.to_csv("productos.csv", index=False)
